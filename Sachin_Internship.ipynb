# %%
from bs4 import BeautifulSoup
import requests

response = requests.get('https://www.expert-seo-training-institute.in/blog/classified-submission-sites/')

response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content)

# %%
list_of_links = []
for link in soup.find_all('a'):
    if link.has_attr('href'):
        list_of_links.append(link.attrs['href'])

# %%
# list_of_links.remove('#')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-cdff3bea3393> in <module>
# ----> 1 list_of_links.remove('#')
#
# ValueError: list.remove(x): x not in list

# %%
len(list_of_links)
# Out:
# 560

# %%
list_of_links
# Out:
# ['https://www.expert-seo-training-institute.in/blog/wp-admin/nav-menus.php',
#  'https://www.expert-seo-training-institute.in/blog/',
#  'https://www.expert-seo-training-institute.in/blog/',
#  'https://www.expert-seo-training-institute.in/blog/category/submission-sites-list/',
#  'https://www.expert-seo-training-institute.in/blog/category/submission-sites-list/',
#  'https://www.expert-seo-training-institute.in/blog/author/admin/',
#  'https://www.expert-seo-training-institute.in/blog/classified-submission-sites/#comments',
#  'https://www.expert-seo-training-institute.in/blog/wp-content/uploads/2018/07/Expert-Training-Institute-2.jpg',
#  'https://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.expert-seo-training-institute.in%2Fblog%2Fclassified-submission-sites%2F',
#  'https://twitter.com/intent/tweet?text=Classified+Submission+Sites+List+2019&url=https%3A%2F%2Fwww.expert-seo-training-institute.in%2Fblog%2Fclassified-submission-sites%2F&via=Expert+Training+Institute',
# ...

# %%
list_of_links.pop(-13)
# Out:
# 'whatsapp://send?text=Classified+Submission+Sites+List+2019 %0A%0A https://www.expert-seo-training-institute.in/blog/classified-submission-sites/'

# %%
list_of_links.pop(9)
# Out:
# 'https://www.expert-seo-training-institute.in/about-pay-per-click.html'

# %%
list_of_links
# Out:
# ['https://www.expert-seo-training-institute.in/blog/wp-admin/nav-menus.php',
#  'https://www.expert-seo-training-institute.in/blog/',
#  'https://www.expert-seo-training-institute.in/blog/',
#  'https://www.expert-seo-training-institute.in/blog/category/submission-sites-list/',
#  'https://www.expert-seo-training-institute.in/blog/category/submission-sites-list/',
#  'https://www.expert-seo-training-institute.in/blog/author/admin/',
#  'https://www.expert-seo-training-institute.in/blog/classified-submission-sites/#comments',
#  'https://www.expert-seo-training-institute.in/blog/wp-content/uploads/2018/07/Expert-Training-Institute-2.jpg',
#  'https://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.expert-seo-training-institute.in%2Fblog%2Fclassified-submission-sites%2F',
#  'https://www.expert-seo-training-institute.in/blog/increase-website-traffic/',
#  'https://www.expert-seo-training-institute.in/blog/what-is-call-to-action/',
#  'https://www.freeadstime.org/',
# ...

# %%
list_of_links.pop(-13)
# Out:
# 'https://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.expert-seo-training-institute.in%2Fblog%2Fclassified-submission-sites%2F'

# %%
list_of_links.pop(9)
# Out:
# 'https://www.expert-seo-training-institute.in/blog/increase-website-traffic/'

# %%
list_of_links.pop(9)
# Out:
# 'https://www.expert-seo-training-institute.in/blog/what-is-call-to-action/'

# %%
list_of_links.pop(8)
# Out:
# 'https://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.expert-seo-training-institute.in%2Fblog%2Fclassified-submission-sites%2F'

# %%
list_of_links
# Out:
# ['https://www.expert-seo-training-institute.in/blog/wp-admin/nav-menus.php',
#  'https://www.expert-seo-training-institute.in/blog/',
#  'https://www.expert-seo-training-institute.in/blog/',
#  'https://www.expert-seo-training-institute.in/blog/category/submission-sites-list/',
#  'https://www.expert-seo-training-institute.in/blog/category/submission-sites-list/',
#  'https://www.expert-seo-training-institute.in/blog/author/admin/',
#  'https://www.expert-seo-training-institute.in/blog/classified-submission-sites/#comments',
#  'https://www.expert-seo-training-institute.in/blog/wp-content/uploads/2018/07/Expert-Training-Institute-2.jpg',
#  'https://www.freeadstime.org/',
#  'https://www.wallclassifieds.com/',
#  'https://www.giganticlist.com/',
#  'https://www.advertiseera.com/',
#  'https://www.h1ad.com/',
#  'https://www.findermaster.com/',
#  'https://www.classifiedsfactor.com/',
#  'https://www.rectanglead.com/',
#  'http://www.classifieds.sulekha.com',
# ...

# %%
# page = requests.get('https://www.landandfarm.com')
# page.status_code
# Out:
# 403
